# %% [markdown]
# <a href="https://colab.research.google.com/github/TruongQuocTruong/CS114.L22.KHCL/blob/main/Crawl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scrapy

# %%
import scrapy

# %%
# %cd "/content/drive/MyDrive/UIT/HK IV/Máy Học/MAY HOC/Sarcasm Detection2"
# Out:
# /content/drive/MyDrive/UIT/HK IV/Máy Học/MAY HOC/Sarcasm Detection2

# %%
# !scrapy startproject google_crawler
# Out:
# New Scrapy project 'google_crawler', using template directory '/usr/local/lib/python3.7/dist-packages/scrapy/templates/project', created in:
#     /content/drive/MyDrive/UIT/HK IV/Máy Học/MAY HOC/Sarcasm Detection2/google_crawler
#
# You can start your first spider with:
#     cd google_crawler
#     scrapy genspider example example.com

# %%
from scrapy.linkextractors import LinkExtractor
import pandas as pd

# %%
# %cd "/content/drive/MyDrive/UIT/HK IV/Máy Học/MAY HOC/Sarcasm Detection2/google_crawler/google_crawler"
# Out:
# /content/drive/MyDrive/UIT/HK IV/Máy Học/MAY HOC/Sarcasm Detection2/google_crawler/google_crawler

# %%
# !bash
# Out:
# bash: cannot set terminal process group (60): Inappropriate ioctl for device
# bash: no job control in this shell
# er/google_crawler# scrapy crawl Hollywood -o HollyWood.json
# 2021-06-13 09:36:31 [scrapy.utils.log] INFO: Scrapy 2.5.0 started (bot: google_crawler)
# 2021-06-13 09:36:31 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.2.0, Python 3.7.10 (default, May  3 2021, 02:48:31) - [GCC 7.5.0], pyOpenSSL 20.0.1 (OpenSSL 1.1.1k  25 Mar 2021), cryptography 3.4.7, Platform Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic
# 2021-06-13 09:36:31 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/scrapy/spiderloader.py", line 75, in load
#     return self._spiders[spider_name]
# KeyError: 'Hollywood'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
scrapy shell 'https://hollywoodlife.com/'
scrapy crawl HollyWood -o HollyWood.json

response.css('div.article-feed__article-details').get()
response.css('h3.article-feed__article-title').css('a::attr(href)').get()
response.css('h3.article-feed__article-title').css('a::text').get()
response.css('span.pagination-nav__next').css('a::attr(href)').get()
